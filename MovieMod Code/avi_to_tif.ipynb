# %% [markdown]
# # Convert .avi to .tif (Step 1)
#
# This code is super simple because it is pulling from .miniscope_to_tif
#
# The purpose is to do a batch conversion and concatenation of all of your .avi files into tifs

# %%
# unpack nwb file movies into .tif files
from pynwb import NWBHDF5IO
from tifffile import imsave, memmap, imread, imwrite, TiffFile
import glob
import numpy as np
import os
import psutil
from pynwb import NWBHDF5IO
from scipy.signal import detrend
import matplotlib.pyplot as plt
import imageio
import cv2

# only works if caiman is environment
try:
    import caiman as cm
except:
    print("CaImAn toolbox not loaded. Add to environment if running calcium imaging analysis")
    pass

#% 
def avi_to_tif(movie_path: str):
    # redundant
    miniscope_to_tif(movie_path = movie_path)

#% helper functions
def mp4_to_tif(movie_path: str):
    '''
    mp4_to_tif:
        This function is used to convert lionheart data to .tif files for analysis

    Args:
        >>> movie_path: string to the filetype of interest ending in '.mp4'
        >>> idx_movie: int representing the index that contains your movie. 
                These files are saved as multi-image stacks. One of them is important.
                To figure this out:
                    vid = imageio.get_reader(movie_path,  'ffmpeg')
                    plt.imshow(vid)

    '''

    # load ffmpeg backend
    vid = imageio.get_reader(movie_path,  'ffmpeg')
    vid.get_meta_data()

    # interface with user
    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10,5))
    ax[0].imshow(vid.get_data(0)[::2,::2,0])
    ax[0].set_title("Dimension 1")
    ax[1].imshow(vid.get_data(0)[::2,::2,1])
    ax[1].set_title("Dimension 2")
    ax[2].imshow(vid.get_data(0)[::2,::2,2])
    ax[2].set_title("Dimension 3")
    plt.show()

    # require user interface (-1 bc 0 indexing in python)
    idx_movie = int(input("Enter which dimension [1/2/3] has your data:"))-1

    # get downsample factor interactively
    downsample_factor = interactive_downsample(image = vid.get_data(0)[:,:,idx_movie])

    # run a while loop to extract data
    images = []
    next = 0; counter = 0

    # create new name for tif file
    fname = movie_path.split('.mp4')[0]+'.tif'

    # get pixel shape
    if downsample_factor is None:
        pixel_shape = vid.get_meta_data()['size']
    else:
        pixel_shape = vid.get_data(0)[::downsample_factor,::downsample_factor,idx_movie].shape

    # get movie length
    counter = 0; next = 0
    while next == 0:
        try:
            vid.get_data(counter)
            counter += 1
        except:
            next = 1
    
    # create a memory mappable file
    im = memmap(
        fname,
        shape=(counter,pixel_shape[0],pixel_shape[1]),
        dtype=np.uint16,
        append=True
    )

    # now we will append to memory mapped file
    print("Please wait while data is mapped to:",fname)
    next = 0; counter = 0
    while next == 0:
        try:
            if downsample_factor is None:
                im[counter]=vid.get_data(counter)[:,:,idx_movie]
            else:
                im[counter]=vid.get_data(counter)[::downsample_factor,::downsample_factor,idx_movie]
            im.flush()  
            print("Finished with image",counter)                     
            counter += 1
        except:
            next = 1

    return fname

# TODO: FINISH
def wmv_to_tif(movie_path: str, image_idx = None, downsample_factor = None, save_path = None):

    '''
    Args:
        >>> movie_path: directory with movie
        >>> image_idx: index containing your image if known (cv reader pulls in duplicates or blank 3D)
        >>> downsample_factor: factor by which to spatially reduce your video
        >>> save_path: path to write your video with '.tif' extension
    
    '''

    # load example video
    if 'vid' in locals():
        del vid
    vid = cv2.VideoCapture(movie_path)
    vid.grab()

    # get image
    retval, image = vid.retrieve()    

    if image_idx is None:
        # interface with user
        fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10,5))
        ax[0].imshow(image[::2,::2,0])
        ax[0].set_title("Dimension 1")
        ax[1].imshow(image[::2,::2,1])
        ax[1].set_title("Dimension 2")
        ax[2].imshow(image[::2,::2,2])
        ax[2].set_title("Dimension 3")
        plt.show()

        # require user interface (-1 bc 0 indexing in python)
        idx_movie = int(input("Enter which dimension [1/2/3] has your data:"))-1
    else:
        # make sure this is the correct indexing
        idx_movie = image_idx

    if downsample_factor is None:
        # get downsample factor interactively
        downsample_factor = interactive_downsample(image = image[:,:,idx_movie])

    # run a while loop to extract data
    images = []
    next = 0; counter = 0

    # get pixel shape
    if downsample_factor is None:
        pixel_shape = image['size']
    else:
        pixel_shape = image[::downsample_factor,::downsample_factor,idx_movie].shape

    # get movie length
    counter = 0; next = 0; del vid
    # load example video
    if 'vid' in locals():
        del vid
    vid = cv2.VideoCapture(movie_path)
    while True:
        vid.grab()
        retval, image = vid.retrieve()

        if not retval:
            break
        else:
            counter += 1

    # create a memory mappable file
    if save_path is None:

        # create new name for tif file
        fname = movie_path.split('.')[0]+'.tif'

    else:
        file_name = os.path.split(movie_path)[1].split('.')[0]
        fname = os.path.join(save_path,file_name+'.tif')
    
    # write a memory mapped file
    im = memmap(
        fname,
        shape=(counter,pixel_shape[0],pixel_shape[1]),
        dtype=np.uint16,
        append=True
    )

    # TODO: FINISH THIS

    # now we will append to memory mapped file
    print("Please wait while data is mapped to:",fname)
    next = 0; counter = 0
    vid = cv2.VideoCapture(movie_path)
    while True:
        # get video
        vid.grab()
        retval, image = vid.retrieve()
        if retval is True:
            # downsample
            if downsample_factor is None:
                im[counter]=image[:,:,idx_movie]
            else:
                im[counter]=image[::downsample_factor,::downsample_factor,idx_movie]
            counter += 1
        if not retval:
            break

    #images_new = imread(fname)
    return fname

# TODO: FINISH
def batch_to_tif(files_path: str, image_idx = None, downsample_factor = None, save_path = None):
    '''
    Write a bunch of files in batch
    
    Args:
        >>> files_path: path with all of your files
        >>> extension_type: what file type your files are
    '''

    # get contents
    dir_contents = sorted(os.listdir(files_path))

    # for loop
    for vidname in dir_contents:
        movie_path = os.path.join(files_path,vidname)
        print(movie_path)
        if '.wmv' in vidname:
            fname = wmv_to_tif(movie_path = os.path.join(files_path,vidname), image_idx = image_idx, downsample_factor = downsample_factor, save_path = save_path)

# downsample tif file
def downsample_tif(movie_path: str):
    '''
    downsample_to_tif:
        This function is used to convert lionheart data to .tif files for analysis

    Args:
        >>> movie_path: string to the filetype of interest ending in '.mp4'
        >>> idx_movie: int representing the index that contains your movie. 
                These files are saved as multi-image stacks. One of them is important.
                To figure this out:
                    vid = imageio.get_reader(movie_path,  'ffmpeg')
                    plt.imshow(vid)

    '''

    # load ffmpeg backend
    vid = imageio.get_reader(movie_path,  'ffmpeg')
    vid.get_meta_data()

    # interface with user
    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10,5))
    ax[0].imshow(vid.get_data(0)[::2,::2,0])
    ax[0].set_title("Dimension 1")
    ax[1].imshow(vid.get_data(0)[::2,::2,1])
    ax[1].set_title("Dimension 2")
    ax[2].imshow(vid.get_data(0)[::2,::2,2])
    ax[2].set_title("Dimension 3")
    plt.show()

    # require user interface (-1 bc 0 indexing in python)
    idx_movie = int(input("Enter which dimension [1/2/3] has your data:"))-1

    # get downsample factor interactively
    downsample_factor = interactive_downsample(image = vid.get_data(0)[:,:,idx_movie])

    # run a while loop to extract data
    images = []
    next = 0; counter = 0

    # create new name for tif file
    fname = movie_path.split('.tif')[0]+'_downsampled.tif'

    # get pixel shape
    if downsample_factor is None:
        pixel_shape = vid.get_meta_data()['size']
    else:
        pixel_shape = vid.get_data(0)[::downsample_factor,::downsample_factor,idx_movie].shape

    # get movie length
    counter = 0; next = 0
    while next == 0:
        try:
            vid.get_data(counter)
            counter += 1
        except:
            next = 1
    
    # create a memory mappable file
    im = memmap(
        fname,
        shape=(counter,pixel_shape[0],pixel_shape[1]),
        dtype=np.uint16,
        append=True
    )

    # now we will append to memory mapped file
    print("Please wait while data is mapped to:",fname)
    next = 0; counter = 0
    while next == 0:
        try:
            if downsample_factor is None:
                im[counter]=vid.get_data(counter)[:,:,idx_movie]
            else:
                im[counter]=vid.get_data(counter)[::downsample_factor,::downsample_factor,idx_movie]
            im.flush()  
            print("Finished with image",counter)                     
            counter += 1
        except:
            next = 1

# split 4D tif file
def split_4D_tif(movie_path: str, structural_index = None, functional_index = None):

    """
    This function will take a 4D movie, split it into its components based on your index, 
    then save the output based on the save name index.

    This function was specifically designed when one records a structural channel with a functional channel. 
    For example, you might record astrocytes with an RFP, but neurons or all cells with a GCaMP.

    Args:
        movie_path: tiff file path
        structural_index: index for structural imaging
        functional_index: index for functional imaging

    output:
        self.fname_struct: structural fname
        self.fname_funct: functional fname  
    
    """

    # load movie
    movie = lazyTiff(movie_path)

    if structural_index is None or functional_index is None:
        idx = np.argmin(movie.shape)
        fig, ax = plt.subplots(nrows=1, ncols=2, figsize = (5, 2.5))

        if idx == 1:
            ax[0].imshow(movie[0,0,:,:])
            ax[1].imshow(movie[0,1,:,:])
            functional_index = int(input("Which subplot is your functional image? [1 or 2]: "))-1
            if functional_index == 0:
                structural_index = 1
            elif functional_index == 1:
                structural_index = 0

    # get file_root
    file_root = movie_path.split('.tif')[0]

    # create new name        
    fname_funct = file_root+'_functional.tif'
    fname_struct = file_root+'_structural.tif'
    print("Saving functional output as",fname_funct)
    print("Saving structural output as",fname_struct)

    # split data
    structMovie = movie[:,structural_index,:,:]
    functMovie = movie[:,functional_index,:,:]        
    imsave(fname_struct,structMovie)  
    imsave(fname_funct,functMovie) 

    return [fname_funct], [fname_struct], structMovie, functMovie 

# NOT WORKING  
def miniscope_to_tif(movie_path: str):

    '''
    Args: 
        >>> movie_path: path to data containing .avi files
            __/FOLDER__
                --> 0.avi
                --> 1.avi

    This code will save out a stacked .tif file and provide options for downsampling

    John Stout  
    '''

    # get all .avi files on path
    pathnames = glob.glob(movie_path+'/*.avi')
    pathnames.sort()
    num_files = len(pathnames)

    # use ffmpeg backend for temporary data
    vid = imageio.get_reader(pathnames[0],  'ffmpeg')
    temp_data = vid.get_data(0)

    # load ffmpeg backend
    total_frame_count = []
    for i in pathnames:

        # use ffmpeg backend
        vid = imageio.get_reader(i,  'ffmpeg')
        pixel_shape = vid.get_data(0)[:,:,0].shape 

        # get movie length
        counter = 0; next = 0
        while next == 0:
            try:
                vid.get_data(counter)
                counter += 1
            except:
                next = 1
        
        # create a memory mappable file
        fname = i.split('.avi')[0]+'.tif'
        im = memmap(
            fname,
            shape=(counter,pixel_shape[0],pixel_shape[1]),
            dtype=np.uint16,
            append=True
        )
        total_frame_count.append(counter)

        # now we will append to memory mapped file
        print("Please wait while data is mapped to:",fname)
        next = 0; counter = 0
        while next == 0:
            try:
                im[counter]=vid.get_data(counter)[:,:,0]
                im.flush()  
                print("Finished with image",counter," from movie", i.split('.avi')[-1])                     
                counter += 1
            except:
                next = 1

    # new pathnames
    pathnames = glob.glob(movie_path+'/*.tif')
    pathnames.sort()
    num_files = len(pathnames)                

    # create a memory mappable file
    fname = os.path.join(os.path.split(pathnames[0])[0],'full_movie.tif')
    im = memmap(
        fname,
        shape=(sum(total_frame_count),pixel_shape[0],pixel_shape[1]),
        dtype=np.uint16,
        append=True
    )

    # now we will append to memory mapped file
    print("Please wait while data is mapped to:",fname)
    counter = 0
    for i in range(len(total_frame_count)):
        im[counter:counter+total_frame_count[i],:,:] = imread(pathnames[i]) 
        #im[counter:total_frame_count[i]*(i+1),:,:] = imread(pathnames[i])
        counter += total_frame_count[i]
        print(counter)
        im.flush()
        print("Finished with image",counter+1,"/",len(pathnames))  

# nwb_to_tif converts your nwb file movies to .tif files
def nwb_to_tif(nwbpath: str):
    '''
    Args:
        >>> nwbpath: directory to your nwb file
                >>> e.g. r'/Users/.../filename.nwb'
    
    This file saves out the individual videos in the NWB file as separate .tif files

    - John Stout
    '''

    # directory definitions
    newpath = nwbpath.split('.nwb')[0]
    rootpath = os.path.split(nwbpath)[0]

    # get directory contents
    dir_contents = sorted(os.listdir(rootpath))

    # make new path to save data
    try:
        print("New folder created: ",newpath)
        os.makedirs(newpath)
    except:
        print("Failed to create folder ",newpath, " - this folder may already exist")

    with NWBHDF5IO(nwbpath, "r+") as io:

        # read file
        read_nwbfile = io.read()

        # get the movie names
        movie_names = list(read_nwbfile.acquisition.keys())

        # load movies
        for i in movie_names:

            # load data
            data = read_nwbfile.acquisition[i].data[:]

            # save as .tif
            save_name = ('.').join([i,'tif'])
            print(save_name, "saved to", newpath)
            imsave(os.path.join(newpath,save_name), data)

    return newpath

# tif_to_memmap converts your tif files to memory mapped files
def tif_to_memmap(movie_path: str):
    '''
    This function takes a bunch of .tif files, writes them to memory mapped files, then combines the results.

    Environment required: CAIMAN
    
    Your movies should be saved as .avi or .tif files in a unique folder

    Args: 
        >>> movie_path: directory to your individual movies
    
    '''
    
    # define movie paths
    dir_contents = sorted(os.listdir(movie_path))
    fnames = [os.path.join(movie_path,i) for i in dir_contents if '.tif' in i or '.avi' in i]

    #%% 
        
    print(f"You have {psutil.cpu_count()} CPUs available in your current environment")
    num_processors_to_use = psutil.cpu_count()-1
    print(f"Using",num_processors_to_use, "processors")

    #%% start a cluster for parallel processing (if a cluster already exists it will be closed and a new session will be opened)
    if 'cluster' in locals():  # 'locals' contains list of current local variables
        print('Closing previous cluster')
        cm.stop_server(dview=cluster)
    print("Setting up new cluster")
    dview, cluster, n_processes = cm.cluster.setup_cluster(backend='multiprocessing', 
                                                    n_processes=num_processors_to_use, 
                                                    ignore_preexisting=False)
    print(f"Successfully set up cluster with {n_processes} processes")

    #%% memory map files
    print("Saving out individual memory mapped files...")
    cm.save_memmap_each(fnames, dview = dview, base_name = movie_path.split('/')[-1]+'_', order='C', border_to_0=0)

    #%% join the memory mapped files
    dir_contents_new = sorted(os.listdir(movie_path))
    mmap_names = [i for i in dir_contents_new if '.mmap' in i]
    dir_mmap = [os.path.join(movie_path,i) for i in mmap_names]
    
    print("Joining memory mapped files...")
    cm.save_memmap_join(dir_mmap, base_name = movie_path.split('/')[-1]+'_',dview=dview)

    #%% clean up folder
    print("Removing individual memory mapped files...")
    [os.remove(i) for i in dir_mmap]
    
    # stop running on cluster
    cm.stop_server(dview=cluster)

# lazyTiff reads your tiff file lazily - this is very useful for large files
def lazyTiff(movie_path: str):
    '''
    This function is meant to allow a user to load a large .tif file into memory, by reading the data lazily

    Args:
        movie_path: directory containing your .tif file

    Returns:
        movie: movie from the .tif file

    '''
    movie = memmap(movie_path)

    return movie

# interactively downsample the dataset
def interactive_downsample(image):
    '''
    Args:
        >>> image: example image from a movie

    Returns:
        >>> downsample_factor: chosen downsample factor as an int
    '''

    # plot results of various downsamplings
    fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(10,5))
    ax[0].imshow(image)
    ax[0].set_title("Full Size")   
    ax[1].imshow(image[::2,::2])
    ax[1].set_title("Downsampled x2")       
    ax[2].imshow(image[::4,::4])
    ax[2].set_title("Downsampled x4")      
    ax[3].imshow(image[::6,::6])
    ax[3].set_title("Downsampled x6")   
    plt.show()   

    # now interact with user
    downsample_factor = input("Enter Downsample factor [None, 2, 4, 6, etc...]:")
    if 'None' in downsample_factor:
        downsample_factor = None
    else:
        downsample_factor = int(downsample_factor)
             
    return downsample_factor

# stacktiff allows a user to stack a ton of tiff files into one singular file
def stacktiff(tiff_series_path: str, downsample_factor = None):
    """
    This function takes a folder with a bunch of .tif images and stacks them

    TODO: THIS CODE MUST BE MODIFIED TO MEMORY MAP THE FILES! >>> See mp4_to_tif
    Otherwise, this will be a monster memory bogger

    Args:
        dir: directory containing image data to stack
        dir_save: OPTIONAL but recommended. Directory to save stacked data.
        downsample_factor: OPTIONAL.
            downsample_factor = 2 spatially reduces your dataset by a factor of 2
    """

    # extract all tif data in series
    pathnames = glob.glob(tiff_series_path+'/*.tif')
    pathnames.sort()
    num_files = len(pathnames)

    # read in one image to get shape
    im = imread(pathnames[0])

    # if the size the image is 3D, then just take a sample
    if len(im.shape) > 2:
        im = im[0]

    # get downsample factor interactively
    downsample_factor = interactive_downsample(im)
    if downsample_factor is not None:
        image_shape = im[::downsample_factor,::downsample_factor].shape
    else:
        image_shape = im.shape

    # create new directory to save data
    root_dir = os.path.split(os.path.split(pathnames[0])[0])[0] # select container folder
    new_dir = os.path.join(root_dir,'stacked_series')
    try:
        os.mkdir(new_dir) # make directory
        print("Created new directory:", new_dir)
    except:
        print("Existing directory:", new_dir)

    # get new name
    fname = os.path.join(new_dir,'stacked_series.tif')

    # create a memory mappable file
    im = memmap(
        fname,
        shape=(num_files,image_shape[0],image_shape[1]),
        dtype=np.uint16,
        append=True
    )

    # now we will append to memory mapped file
    print("Please wait while data is mapped to:",fname)
    counter = 0
    for i in pathnames:
        if downsample_factor is None:
            im[counter] = imread(i)
        else:
            im[counter] = imread(i)[::downsample_factor,::downsample_factor]
        im.flush()
        print("Finished with image",counter+1,"/",len(pathnames))  
        counter += 1

# %% [markdown]
# # Convert your movie!

# %%
fname = r'/Users/js0403/miniscope/HPC-Neurons/134A/AAV2/3-Syn-GCaMP8f/2024_02_06/12_35_54/miniscopeDeviceName'

# Here is where you convert as needed
avi_to_tif(movie_path = fname)
# Out:
# Please wait while data is mapped to: /Users/js0403/miniscope/HPC-Neurons/134A/AAV2/3-Syn-GCaMP8f/2024_02_06/12_35_54/miniscopeDeviceName/0.tif
# Finished with image 0  from movie
# Finished with image 1  from movie
# Finished with image 2  from movie
# Finished with image 3  from movie
# Finished with image 4  from movie
# Finished with image 5  from movie
# Finished with image 6  from movie
# Finished with image 7  from movie
# Finished with image 8  from movie
# Finished with image 9  from movie
# Finished with image 10  from movie
# Finished with image 11  from movie
# Finished with image 12  from movie
# Finished with image 13  from movie
# Finished with image 14  from movie
# Finished with image 15  from movie
# Finished with image 16  from movie
# Finished with image 17  from movie
# Finished with image 18  from movie
# Finished with image 19  from movie
# Finished with image 20  from movie
# Finished with image 21  from movie
# Finished with image 22  from movie
# Finished with image 23  from movie
# Finished with image 24  from movie
# Finished with image 25  from movie
# Finished with image 26  from movie
# Finished with image 27  from movie
# Finished with image 28  from movie
# Finished with image 29  from movie
# Finished with image 30  from movie
# Finished with image 31  from movie
# Finished with image 32  from movie
# Finished with image 33  from movie
# Finished with image 34  from movie
# Finished with image 35  from movie
# Finished with image 36  from movie
# Finished with image 37  from movie
# Finished with image 38  from movie
# Finished with image 39  from movie
# Finished with image 40  from movie
# Finished with image 41  from movie
# Finished with image 42  from movie
# Finished with image 43  from movie
# Finished with image 44  from movie
# Finished with image 45  from movie
# Finished with image 46  from movie
# Finished with image 47  from movie
# Finished with image 48  from movie
# Finished with image 49  from movie
# Finished with image 50  from movie
# Finished with image 51  from movie
# Finished with image 52  from movie
# Finished with image 53  from movie
# Finished with image 54  from movie
# Finished with image 55  from movie
# Finished with image 56  from movie
# Finished with image 57  from movie
# Finished with image 58  from movie
# Finished with image 59  from movie
# Finished with image 60  from movie
# Finished with image 61  from movie
# Finished with image 62  from movie
# Finished with image 63  from movie
# Finished with image 64  from movie
# Finished with image 65  from movie
# Finished with image 66  from movie
# Finished with image 67  from movie
# Finished with image 68  from movie
# Finished with image 69  from movie
# Finished with image 70  from movie
# Finished with image 71  from movie
# Finished with image 72  from movie
# Finished with image 73  from movie
# Finished with image 74  from movie
# Finished with image 75  from movie
# Finished with image 76  from movie
# Finished with image 77  from movie
# Finished with image 78  from movie
# Finished with image 79  from movie
# Finished with image 80  from movie
# Finished with image 81  from movie
# Finished with image 82  from movie
# Finished with image 83  from movie
# Finished with image 84  from movie
# Finished with image 85  from movie
# Finished with image 86  from movie
# Finished with image 87  from movie
# Finished with image 88  from movie
# Finished with image 89  from movie
# Finished with image 90  from movie
# Finished with image 91  from movie
# Finished with image 92  from movie
# Finished with image 93  from movie
# Finished with image 94  from movie
# Finished with image 95  from movie
# Finished with image 96  from movie
# Finished with image 97  from movie
# Finished with image 98  from movie
# Finished with image 99  from movie
# Finished with image 100  from movie
# Finished with image 101  from movie
# Finished with image 102  from movie
# Finished with image 103  from movie
# Finished with image 104  from movie
# Finished with image 105  from movie
# Finished with image 106  from movie
# Finished with image 107  from movie
# Finished with image 108  from movie
# Finished with image 109  from movie
# Finished with image 110  from movie
# Finished with image 111  from movie
# Finished with image 112  from movie
# Finished with image 113  from movie
# Finished with image 114  from movie
# Finished with image 115  from movie
# Finished with image 116  from movie
# Finished with image 117  from movie
# Finished with image 118  from movie
# Finished with image 119  from movie
# Finished with image 120  from movie
# Finished with image 121  from movie
# Finished with image 122  from movie
# Finished with image 123  from movie
# Finished with image 124  from movie
# Finished with image 125  from movie
# Finished with image 126  from movie
# Finished with image 127  from movie
# Finished with image 128  from movie
# Finished with image 129  from movie
# Finished with image 130  from movie
# Finished with image 131  from movie
# Finished with image 132  from movie
# Finished with image 133  from movie
# Finished with image 134  from movie
# Finished with image 135  from movie
# Finished with image 136  from movie
# Finished with image 137  from movie
# Finished with image 138  from movie
# Finished with image 139  from movie
# Finished with image 140  from movie
# Finished with image 141  from movie
# Finished with image 142  from movie
# Finished with image 143  from movie
# Finished with image 144  from movie
# Finished with image 145  from movie
# Finished with image 146  from movie
# Finished with image 147  from movie
# Finished with image 148  from movie
# Finished with image 149  from movie
# Finished with image 150  from movie
# Finished with image 151  from movie
# Finished with image 152  from movie
# Finished with image 153  from movie
# Finished with image 154  from movie
# Finished with image 155  from movie
# Finished with image 156  from movie
# Finished with image 157  from movie
# Finished with image 158  from movie
# Finished with image 159  from movie
# Finished with image 160  from movie
# Finished with image 161  from movie
# Finished with image 162  from movie
# Finished with image 163  from movie
# Finished with image 164  from movie
# Finished with image 165  from movie
# Finished with image 166  from movie
# Finished with image 167  from movie
# Finished with image 168  from movie
# Finished with image 169  from movie
# Finished with image 170  from movie
# Finished with image 171  from movie
# Finished with image 172  from movie
# Finished with image 173  from movie
# Finished with image 174  from movie
# Finished with image 175  from movie
# Finished with image 176  from movie
# Finished with image 177  from movie
# Finished with image 178  from movie
# Finished with image 179  from movie
# Finished with image 180  from movie
# Finished with image 181  from movie
# Finished with image 182  from movie
# Finished with image 183  from movie
# Finished with image 184  from movie
# Finished with image 185  from movie
# Finished with image 186  from movie
# Finished with image 187  from movie
# Finished with image 188  from movie
# Finished with image 189  from movie
# Finished with image 190  from movie
# Finished with image 191  from movie
# Finished with image 192  from movie
# Finished with image 193  from movie
# Finished with image 194  from movie
# Finished with image 195  from movie
# Finished with image 196  from movie
# Finished with image 197  from movie
# Finished with image 198  from movie
# Finished with image 199  from movie
# Finished with image 200  from movie
# Finished with image 201  from movie
# Finished with image 202  from movie
# Finished with image 203  from movie
# Finished with image 204  from movie
# Finished with image 205  from movie
# Finished with image 206  from movie
# Finished with image 207  from movie
# Finished with image 208  from movie
# Finished with image 209  from movie
# Finished with image 210  from movie
# Finished with image 211  from movie
# Finished with image 212  from movie
# Finished with image 213  from movie
# Finished with image 214  from movie
# Finished with image 215  from movie
# Finished with image 216  from movie
# Finished with image 217  from movie
# Finished with image 218  from movie
# Finished with image 219  from movie
# Finished with image 220  from movie
# Finished with image 221  from movie
# Finished with image 222  from movie
# Finished with image 223  from movie
# Finished with image 224  from movie
# Finished with image 225  from movie
# Finished with image 226  from movie
# Finished with image 227  from movie
# Finished with image 228  from movie
# Finished with image 229  from movie
# Finished with image 230  from movie
# Finished with image 231  from movie
# Finished with image 232  from movie
# Finished with image 233  from movie
# Finished with image 234  from movie
# Finished with image 235  from movie
# Finished with image 236  from movie
# Finished with image 237  from movie
# Finished with image 238  from movie
# Finished with image 239  from movie
# Finished with image 240  from movie
# Finished with image 241  from movie
# Finished with image 242  from movie
# Finished with image 243  from movie
# Finished with image 244  from movie
# Finished with image 245  from movie
# Finished with image 246  from movie
# Finished with image 247  from movie
# Finished with image 248  from movie
# Finished with image 249  from movie
# Finished with image 250  from movie
# Finished with image 251  from movie
# Finished with image 252  from movie
# Finished with image 253  from movie
# Finished with image 254  from movie
# Finished with image 255  from movie
# Finished with image 256  from movie
# Finished with image 257  from movie
# Finished with image 258  from movie
# Finished with image 259  from movie
# Finished with image 260  from movie
# Finished with image 261  from movie
# Finished with image 262  from movie
# Finished with image 263  from movie
# Finished with image 264  from movie
# Finished with image 265  from movie
# Finished with image 266  from movie
# Finished with image 267  from movie
# Finished with image 268  from movie
# Finished with image 269  from movie
# Finished with image 270  from movie
# Finished with image 271  from movie
# Finished with image 272  from movie
# Finished with image 273  from movie
# Finished with image 274  from movie
# Finished with image 275  from movie
# Finished with image 276  from movie
# Finished with image 277  from movie
# Finished with image 278  from movie
# Finished with image 279  from movie
# Finished with image 280  from movie
# Finished with image 281  from movie
# Finished with image 282  from movie
# Finished with image 283  from movie
# Finished with image 284  from movie
# Finished with image 285  from movie
# Finished with image 286  from movie
# Finished with image 287  from movie
# Finished with image 288  from movie
# Finished with image 289  from movie
# Finished with image 290  from movie
# Finished with image 291  from movie
# Finished with image 292  from movie
# Finished with image 293  from movie
# Finished with image 294  from movie
# Finished with image 295  from movie
# Finished with image 296  from movie
# Finished with image 297  from movie
# Finished with image 298  from movie
# Finished with image 299  from movie
# Finished with image 300  from movie
# Finished with image 301  from movie
# Finished with image 302  from movie
# Finished with image 303  from movie
# Finished with image 304  from movie
# Finished with image 305  from movie
# Finished with image 306  from movie
# Finished with image 307  from movie
# Finished with image 308  from movie
# Finished with image 309  from movie
# Finished with image 310  from movie
# Finished with image 311  from movie
# Finished with image 312  from movie
# Finished with image 313  from movie
# Finished with image 314  from movie
# Finished with image 315  from movie
# Finished with image 316  from movie
# Finished with image 317  from movie
# Finished with image 318  from movie
# Finished with image 319  from movie
# Finished with image 320  from movie
# Finished with image 321  from movie
# Finished with image 322  from movie
# Finished with image 323  from movie
# Finished with image 324  from movie
# Finished with image 325  from movie
# Finished with image 326  from movie
# Finished with image 327  from movie
# Finished with image 328  from movie
# Finished with image 329  from movie
# Finished with image 330  from movie
# Finished with image 331  from movie
# Finished with image 332  from movie
# Finished with image 333  from movie
# Finished with image 334  from movie
# Finished with image 335  from movie
# Finished with image 336  from movie
# Finished with image 337  from movie
# Finished with image 338  from movie
# Finished with image 339  from movie
# Finished with image 340  from movie
# Finished with image 341  from movie
# Finished with image 342  from movie
# Finished with image 343  from movie
# Finished with image 344  from movie
# Finished with image 345  from movie
# Finished with image 346  from movie
# Finished with image 347  from movie
# Finished with image 348  from movie
# Finished with image 349  from movie
# Finished with image 350  from movie
# Finished with image 351  from movie
# Finished with image 352  from movie
# Finished with image 353  from movie
# Finished with image 354  from movie
# Finished with image 355  from movie
# Finished with image 356  from movie
# Finished with image 357  from movie
# Finished with image 358  from movie
# Finished with image 359  from movie
# Finished with image 360  from movie
# Finished with image 361  from movie
# Finished with image 362  from movie
# Finished with image 363  from movie
# Finished with image 364  from movie
# Finished with image 365  from movie
# Finished with image 366  from movie
# Finished with image 367  from movie
# Finished with image 368  from movie
# Finished with image 369  from movie
# Finished with image 370  from movie
# Finished with image 371  from movie
# Finished with image 372  from movie
# Finished with image 373  from movie
# Finished with image 374  from movie
# Finished with image 375  from movie
# Finished with image 376  from movie
# Finished with image 377  from movie
# Finished with image 378  from movie
# Finished with image 379  from movie
# Finished with image 380  from movie
# Finished with image 381  from movie
# Finished with image 382  from movie
# Finished with image 383  from movie
# Finished with image 384  from movie
# Finished with image 385  from movie
# Finished with image 386  from movie
# Finished with image 387  from movie
# Finished with image 388  from movie
# Finished with image 389  from movie
# Finished with image 390  from movie
# Finished with image 391  from movie
# Finished with image 392  from movie
# Finished with image 393  from movie
# Finished with image 394  from movie
# Finished with image 395  from movie
# Finished with image 396  from movie
# Finished with image 397  from movie
# Finished with image 398  from movie
# Finished with image 399  from movie
# Finished with image 400  from movie
# Finished with image 401  from movie
# Finished with image 402  from movie
# Finished with image 403  from movie
# Finished with image 404  from movie
# Finished with image 405  from movie
# Finished with image 406  from movie
# Finished with image 407  from movie
# Finished with image 408  from movie
# Finished with image 409  from movie
# Finished with image 410  from movie
# Finished with image 411  from movie
# Finished with image 412  from movie
# Finished with image 413  from movie
# Finished with image 414  from movie
# Finished with image 415  from movie
# Finished with image 416  from movie
# Finished with image 417  from movie
# Finished with image 418  from movie
# Finished with image 419  from movie
# Finished with image 420  from movie
# Finished with image 421  from movie
# Finished with image 422  from movie
# Finished with image 423  from movie
# Finished with image 424  from movie
# Finished with image 425  from movie
# Finished with image 426  from movie
# Finished with image 427  from movie
# Finished with image 428  from movie
# Finished with image 429  from movie
# Finished with image 430  from movie
# Finished with image 431  from movie
# Finished with image 432  from movie
# Finished with image 433  from movie
# Finished with image 434  from movie
# Finished with image 435  from movie
# Finished with image 436  from movie
# Finished with image 437  from movie
# Finished with image 438  from movie
# Finished with image 439  from movie
# Finished with image 440  from movie
# Finished with image 441  from movie
# Finished with image 442  from movie
# Finished with image 443  from movie
# Finished with image 444  from movie
# Finished with image 445  from movie
# Finished with image 446  from movie
# Finished with image 447  from movie
# Finished with image 448  from movie
# Finished with image 449  from movie
# Finished with image 450  from movie
# Finished with image 451  from movie
# Finished with image 452  from movie
# Finished with image 453  from movie
# Finished with image 454  from movie
# Finished with image 455  from movie
# Finished with image 456  from movie
# Finished with image 457  from movie
# Finished with image 458  from movie
# Finished with image 459  from movie
# Finished with image 460  from movie
# Finished with image 461  from movie
# Finished with image 462  from movie
# Finished with image 463  from movie
# Finished with image 464  from movie
# Finished with image 465  from movie
# Finished with image 466  from movie
# Finished with image 467  from movie
# Finished with image 468  from movie
# Finished with image 469  from movie
# Finished with image 470  from movie
# Finished with image 471  from movie
# Finished with image 472  from movie
# Finished with image 473  from movie
# Finished with image 474  from movie
# Finished with image 475  from movie
# Finished with image 476  from movie
# Finished with image 477  from movie
# Finished with image 478  from movie
# Finished with image 479  from movie
# Finished with image 480  from movie
# Finished with image 481  from movie
# Finished with image 482  from movie
# Finished with image 483  from movie
# Finished with image 484  from movie
# Finished with image 485  from movie
# Finished with image 486  from movie
# Finished with image 487  from movie
# Finished with image 488  from movie
# Finished with image 489  from movie
# Finished with image 490  from movie
# Finished with image 491  from movie
# Finished with image 492  from movie
# Finished with image 493  from movie
# Finished with image 494  from movie
# Finished with image 495  from movie
# Finished with image 496  from movie
# Finished with image 497  from movie
# Finished with image 498  from movie
# Finished with image 499  from movie
# Finished with image 500  from movie
# Finished with image 501  from movie
# Finished with image 502  from movie
# Finished with image 503  from movie
# Finished with image 504  from movie
# Finished with image 505  from movie
# Finished with image 506  from movie
# Finished with image 507  from movie
# Finished with image 508  from movie
# Finished with image 509  from movie
# Finished with image 510  from movie
# Finished with image 511  from movie
# Finished with image 512  from movie
# Finished with image 513  from movie
# Finished with image 514  from movie
# Finished with image 515  from movie
# Finished with image 516  from movie
# Finished with image 517  from movie
# Finished with image 518  from movie
# Finished with image 519  from movie
# Finished with image 520  from movie
# Finished with image 521  from movie
# Finished with image 522  from movie
# Finished with image 523  from movie
# Finished with image 524  from movie
# Finished with image 525  from movie
# Finished with image 526  from movie
# Finished with image 527  from movie
# Finished with image 528  from movie
# Finished with image 529  from movie
# Finished with image 530  from movie
# Finished with image 531  from movie
# Finished with image 532  from movie
# Finished with image 533  from movie
# Finished with image 534  from movie
# Finished with image 535  from movie
# Finished with image 536  from movie
# Finished with image 537  from movie
# Finished with image 538  from movie
# Finished with image 539  from movie
# Finished with image 540  from movie
# Finished with image 541  from movie
# Finished with image 542  from movie
# Finished with image 543  from movie
# Finished with image 544  from movie
# Finished with image 545  from movie
# Finished with image 546  from movie
# Finished with image 547  from movie
# Finished with image 548  from movie
# Finished with image 549  from movie
# Finished with image 550  from movie
# Finished with image 551  from movie
# Finished with image 552  from movie
# Finished with image 553  from movie
# Finished with image 554  from movie
# Finished with image 555  from movie
# Finished with image 556  from movie
# Finished with image 557  from movie
# Finished with image 558  from movie
# Finished with image 559  from movie
# Finished with image 560  from movie
# Finished with image 561  from movie
# Finished with image 562  from movie
# Finished with image 563  from movie
# Finished with image 564  from movie
# Finished with image 565  from movie
# Finished with image 566  from movie
# Finished with image 567  from movie
# Finished with image 568  from movie
# Finished with image 569  from movie
# Finished with image 570  from movie
# Finished with image 571  from movie
# Finished with image 572  from movie
# Finished with image 573  from movie
# Finished with image 574  from movie
# Finished with image 575  from movie
# Finished with image 576  from movie
# Finished with image 577  from movie
# Finished with image 578  from movie
# Finished with image 579  from movie
# Finished with image 580  from movie
# Finished with image 581  from movie
# Finished with image 582  from movie
# Finished with image 583  from movie
# Finished with image 584  from movie
# Finished with image 585  from movie
# Finished with image 586  from movie
# Finished with image 587  from movie
# Finished with image 588  from movie
# Finished with image 589  from movie
# Finished with image 590  from movie
# Finished with image 591  from movie
# Finished with image 592  from movie
# Finished with image 593  from movie
# Finished with image 594  from movie
# Finished with image 595  from movie
# Finished with image 596  from movie
# Finished with image 597  from movie
# Finished with image 598  from movie
# Finished with image 599  from movie
# Finished with image 600  from movie
# Finished with image 601  from movie
# Finished with image 602  from movie
# Finished with image 603  from movie
# Finished with image 604  from movie
# Finished with image 605  from movie
# Finished with image 606  from movie
# Finished with image 607  from movie
# Finished with image 608  from movie
# Finished with image 609  from movie
# Finished with image 610  from movie
# Finished with image 611  from movie
# Finished with image 612  from movie
# Finished with image 613  from movie
# Finished with image 614  from movie
# Finished with image 615  from movie
# Finished with image 616  from movie
# Finished with image 617  from movie
# Finished with image 618  from movie
# Finished with image 619  from movie
# Finished with image 620  from movie
# Finished with image 621  from movie
# Finished with image 622  from movie
# Finished with image 623  from movie
# Finished with image 624  from movie
# Finished with image 625  from movie
# Finished with image 626  from movie
# Finished with image 627  from movie
# Finished with image 628  from movie
# Finished with image 629  from movie
# Finished with image 630  from movie
# Finished with image 631  from movie
# Finished with image 632  from movie
# Finished with image 633  from movie
# Finished with image 634  from movie
# Finished with image 635  from movie
# Finished with image 636  from movie
# Finished with image 637  from movie
# Finished with image 638  from movie
# Finished with image 639  from movie
# Finished with image 640  from movie
# Finished with image 641  from movie
# Finished with image 642  from movie
# Finished with image 643  from movie
# Finished with image 644  from movie
# Finished with image 645  from movie
# Finished with image 646  from movie
# Finished with image 647  from movie
# Finished with image 648  from movie
# Finished with image 649  from movie
# Finished with image 650  from movie
# Finished with image 651  from movie
# Finished with image 652  from movie
# Finished with image 653  from movie
# Finished with image 654  from movie
# Finished with image 655  from movie
# Finished with image 656  from movie
# Finished with image 657  from movie
# Finished with image 658  from movie
# Finished with image 659  from movie
# Finished with image 660  from movie
# Finished with image 661  from movie
# Finished with image 662  from movie
# Finished with image 663  from movie
# Finished with image 664  from movie
# Finished with image 665  from movie
# Finished with image 666  from movie
# Finished with image 667  from movie
# Finished with image 668  from movie
# Finished with image 669  from movie
# Finished with image 670  from movie
# Finished with image 671  from movie
# Finished with image 672  from movie
# Finished with image 673  from movie
# Finished with image 674  from movie
# Finished with image 675  from movie
# Finished with image 676  from movie
# Finished with image 677  from movie
# Finished with image 678  from movie
# Finished with image 679  from movie
# Finished with image 680  from movie
# Finished with image 681  from movie
# Finished with image 682  from movie
# Finished with image 683  from movie
# Finished with image 684  from movie
# Finished with image 685  from movie
# Finished with image 686  from movie
# Finished with image 687  from movie
# Finished with image 688  from movie
# Finished with image 689  from movie
# Finished with image 690  from movie
# Finished with image 691  from movie
# Finished with image 692  from movie
# Finished with image 693  from movie
# Finished with image 694  from movie
# Finished with image 695  from movie
# Finished with image 696  from movie
# Finished with image 697  from movie
# Finished with image 698  from movie
# Finished with image 699  from movie
# Finished with image 700  from movie
# Finished with image 701  from movie
# Finished with image 702  from movie
# Finished with image 703  from movie
# Finished with image 704  from movie
# Finished with image 705  from movie
# Finished with image 706  from movie
# Finished with image 707  from movie
# Finished with image 708  from movie
# Finished with image 709  from movie
# Finished with image 710  from movie
# Finished with image 711  from movie
# Finished with image 712  from movie
# Finished with image 713  from movie
# Finished with image 714  from movie
# Finished with image 715  from movie
# Finished with image 716  from movie
# Finished with image 717  from movie
# Finished with image 718  from movie
# Finished with image 719  from movie
# Finished with image 720  from movie
# Finished with image 721  from movie
# Finished with image 722  from movie
# Finished with image 723  from movie
# Finished with image 724  from movie
# Finished with image 725  from movie
# Finished with image 726  from movie
# Finished with image 727  from movie
# Finished with image 728  from movie
# Finished with image 729  from movie
# Finished with image 730  from movie
# Finished with image 731  from movie
# Finished with image 732  from movie
# Finished with image 733  from movie
# Finished with image 734  from movie
# Finished with image 735  from movie
# Finished with image 736  from movie
# Finished with image 737  from movie
# Finished with image 738  from movie
# Finished with image 739  from movie
# Finished with image 740  from movie
# Finished with image 741  from movie
# Finished with image 742  from movie
# Finished with image 743  from movie
# Finished with image 744  from movie
# Finished with image 745  from movie
# Finished with image 746  from movie
# Finished with image 747  from movie
# Finished with image 748  from movie
# Finished with image 749  from movie
# Finished with image 750  from movie
# Finished with image 751  from movie
# Finished with image 752  from movie
# Finished with image 753  from movie
# Finished with image 754  from movie
# Finished with image 755  from movie
# Finished with image 756  from movie
# Finished with image 757  from movie
# Finished with image 758  from movie
# Finished with image 759  from movie
# Finished with image 760  from movie
# Finished with image 761  from movie
# Finished with image 762  from movie
# Finished with image 763  from movie
# Finished with image 764  from movie
# Finished with image 765  from movie
# Finished with image 766  from movie
# Finished with image 767  from movie
# Finished with image 768  from movie
# Finished with image 769  from movie
# Finished with image 770  from movie
# Finished with image 771  from movie
# Finished with image 772  from movie
# Finished with image 773  from movie
# Finished with image 774  from movie
# Finished with image 775  from movie
# Finished with image 776  from movie
# Finished with image 777  from movie
# Finished with image 778  from movie
# Finished with image 779  from movie
# Finished with image 780  from movie
# Finished with image 781  from movie
# Finished with image 782  from movie
# Finished with image 783  from movie
# Finished with image 784  from movie
# Finished with image 785  from movie
# Finished with image 786  from movie
# Finished with image 787  from movie
# Finished with image 788  from movie
# Finished with image 789  from movie
# Finished with image 790  from movie
# Finished with image 791  from movie
# Finished with image 792  from movie
# Finished with image 793  from movie
# Finished with image 794  from movie
# Finished with image 795  from movie
# Finished with image 796  from movie
# Finished with image 797  from movie
# Finished with image 798  from movie
# Finished with image 799  from movie
# Finished with image 800  from movie
# Finished with image 801  from movie
# Finished with image 802  from movie
# Finished with image 803  from movie
# Finished with image 804  from movie
# Finished with image 805  from movie
# Finished with image 806  from movie
# Finished with image 807  from movie
# Finished with image 808  from movie
# Finished with image 809  from movie
# Finished with image 810  from movie
# Finished with image 811  from movie
# Finished with image 812  from movie
# Finished with image 813  from movie
# Finished with image 814  from movie
# Finished with image 815  from movie
# Finished with image 816  from movie
# Finished with image 817  from movie
# Finished with image 818  from movie
# Finished with image 819  from movie
# Finished with image 820  from movie
# Finished with image 821  from movie
# Finished with image 822  from movie
# Finished with image 823  from movie
# Finished with image 824  from movie
# Finished with image 825  from movie
# Finished with image 826  from movie
# Finished with image 827  from movie
# Finished with image 828  from movie
# Finished with image 829  from movie
# Finished with image 830  from movie
# Finished with image 831  from movie
# Finished with image 832  from movie
# Finished with image 833  from movie
# Finished with image 834  from movie
# Finished with image 835  from movie
# Finished with image 836  from movie
# Finished with image 837  from movie
# Finished with image 838  from movie
# Finished with image 839  from movie
# Finished with image 840  from movie
# Finished with image 841  from movie
# Finished with image 842  from movie
# Finished with image 843  from movie
# Finished with image 844  from movie
# Finished with image 845  from movie
# Finished with image 846  from movie
# Finished with image 847  from movie
# Finished with image 848  from movie
# Finished with image 849  from movie
# Finished with image 850  from movie
# Finished with image 851  from movie
# Finished with image 852  from movie
# Finished with image 853  from movie
# Finished with image 854  from movie
# Finished with image 855  from movie
# Finished with image 856  from movie
# Finished with image 857  from movie
# Finished with image 858  from movie
# Finished with image 859  from movie
# Finished with image 860  from movie
# Finished with image 861  from movie
# Finished with image 862  from movie
# Finished with image 863  from movie
# Finished with image 864  from movie
# Finished with image 865  from movie
# Finished with image 866  from movie
# Finished with image 867  from movie
# Finished with image 868  from movie
# Finished with image 869  from movie
# Finished with image 870  from movie
# Finished with image 871  from movie
# Finished with image 872  from movie
# Finished with image 873  from movie
# Finished with image 874  from movie
# Finished with image 875  from movie
# Finished with image 876  from movie
# Finished with image 877  from movie
# Finished with image 878  from movie
# Finished with image 879  from movie
# Finished with image 880  from movie
# Finished with image 881  from movie
# Finished with image 882  from movie
# Finished with image 883  from movie
# Finished with image 884  from movie
# Finished with image 885  from movie
# Finished with image 886  from movie
# Finished with image 887  from movie
# Finished with image 888  from movie
# Finished with image 889  from movie
# Finished with image 890  from movie
# Finished with image 891  from movie
# Finished with image 892  from movie
# Finished with image 893  from movie
# Finished with image 894  from movie
# Finished with image 895  from movie
# Finished with image 896  from movie
# Finished with image 897  from movie
# Finished with image 898  from movie
# Finished with image 899  from movie
# Finished with image 900  from movie
# Finished with image 901  from movie
# Finished with image 902  from movie
# Finished with image 903  from movie
# Finished with image 904  from movie
# Finished with image 905  from movie
# Finished with image 906  from movie
# Finished with image 907  from movie
# Finished with image 908  from movie
# Finished with image 909  from movie
# Finished with image 910  from movie
# Finished with image 911  from movie
# Finished with image 912  from movie
# Finished with image 913  from movie
# Finished with image 914  from movie
# Finished with image 915  from movie
# Finished with image 916  from movie
# Finished with image 917  from movie
# Finished with image 918  from movie
# Finished with image 919  from movie
# Finished with image 920  from movie
# Finished with image 921  from movie
# Finished with image 922  from movie
# Finished with image 923  from movie
# Finished with image 924  from movie
# Finished with image 925  from movie
# Finished with image 926  from movie
# Finished with image 927  from movie
# Finished with image 928  from movie
# Finished with image 929  from movie
# Finished with image 930  from movie
# Finished with image 931  from movie
# Finished with image 932  from movie
# Finished with image 933  from movie
# Finished with image 934  from movie
# Finished with image 935  from movie
# Finished with image 936  from movie
# Finished with image 937  from movie
# Finished with image 938  from movie
# Finished with image 939  from movie
# Finished with image 940  from movie
# Finished with image 941  from movie
# Finished with image 942  from movie
# Finished with image 943  from movie
# Finished with image 944  from movie
# Finished with image 945  from movie
# Finished with image 946  from movie
# Finished with image 947  from movie
# Finished with image 948  from movie
# Finished with image 949  from movie
# Finished with image 950  from movie
# Finished with image 951  from movie
# Finished with image 952  from movie
# Finished with image 953  from movie
# Finished with image 954  from movie
# Finished with image 955  from movie
# Finished with image 956  from movie
# Finished with image 957  from movie
# Finished with image 958  from movie
# Finished with image 959  from movie
# Finished with image 960  from movie
# Finished with image 961  from movie
# Finished with image 962  from movie
# Finished with image 963  from movie
# Finished with image 964  from movie
# Finished with image 965  from movie
# Finished with image 966  from movie
# Finished with image 967  from movie
# Finished with image 968  from movie
# Finished with image 969  from movie
# Finished with image 970  from movie
# Finished with image 971  from movie
# Finished with image 972  from movie
# Finished with image 973  from movie
# Finished with image 974  from movie
# Finished with image 975  from movie
# Finished with image 976  from movie
# Finished with image 977  from movie
# Finished with image 978  from movie
# Finished with image 979  from movie
# Finished with image 980  from movie
# Finished with image 981  from movie
# Finished with image 982  from movie
# Finished with image 983  from movie
# Finished with image 984  from movie
# Finished with image 985  from movie
# Finished with image 986  from movie
# Finished with image 987  from movie
# Finished with image 988  from movie
# Finished with image 989  from movie
# Finished with image 990  from movie
# Finished with image 991  from movie
# Finished with image 992  from movie
# Finished with image 993  from movie
# Finished with image 994  from movie
# Finished with image 995  from movie
# Finished with image 996  from movie
# Finished with image 997  from movie
# Finished with image 998  from movie
# Finished with image 999  from movie
# Please wait while data is mapped to: /Users/js0403/miniscope/HPC-Neurons/134A/AAV2/3-Syn-GCaMP8f/2024_02_06/12_35_54/miniscopeDeviceName/1.tif
# Finished with image 0  from movie
# Finished with image 1  from movie
# Finished with image 2  from movie
# Finished with image 3  from movie
# Finished with image 4  from movie
# Finished with image 5  from movie
# Finished with image 6  from movie
# Finished with image 7  from movie
# Finished with image 8  from movie
# Finished with image 9  from movie
# Finished with image 10  from movie
# Finished with image 11  from movie
# Finished with image 12  from movie
# Finished with image 13  from movie
# Finished with image 14  from movie
# Finished with image 15  from movie
# Finished with image 16  from movie
# Finished with image 17  from movie
# Finished with image 18  from movie
# Finished with image 19  from movie
# Finished with image 20  from movie
# Finished with image 21  from movie
# Finished with image 22  from movie
# Finished with image 23  from movie
# Finished with image 24  from movie
# Finished with image 25  from movie
# Finished with image 26  from movie
# Finished with image 27  from movie
# Finished with image 28  from movie
# Finished with image 29  from movie
# Finished with image 30  from movie
# Finished with image 31  from movie
# Finished with image 32  from movie
# Finished with image 33  from movie
# Finished with image 34  from movie
# Finished with image 35  from movie
# Finished with image 36  from movie
# Finished with image 37  from movie
# Finished with image 38  from movie
# Finished with image 39  from movie
# Finished with image 40  from movie
# Finished with image 41  from movie
# Finished with image 42  from movie
# Finished with image 43  from movie
# Finished with image 44  from movie
# Finished with image 45  from movie
# Finished with image 46  from movie
# Finished with image 47  from movie
# Finished with image 48  from movie
# Finished with image 49  from movie
# Finished with image 50  from movie
# Finished with image 51  from movie
# Finished with image 52  from movie
# Finished with image 53  from movie
# Finished with image 54  from movie
# Finished with image 55  from movie
# Finished with image 56  from movie
# Finished with image 57  from movie
# Finished with image 58  from movie
# Finished with image 59  from movie
# Finished with image 60  from movie
# Finished with image 61  from movie
# Finished with image 62  from movie
# Finished with image 63  from movie
# Finished with image 64  from movie
# Finished with image 65  from movie
# Finished with image 66  from movie
# Finished with image 67  from movie
# Finished with image 68  from movie
# Finished with image 69  from movie
# Finished with image 70  from movie
# Finished with image 71  from movie
# Finished with image 72  from movie
# Finished with image 73  from movie
# Finished with image 74  from movie
# Finished with image 75  from movie
# Finished with image 76  from movie
# Finished with image 77  from movie
# Finished with image 78  from movie
# Finished with image 79  from movie
# Finished with image 80  from movie
# Finished with image 81  from movie
# Finished with image 82  from movie
# Finished with image 83  from movie
# Finished with image 84  from movie
# Finished with image 85  from movie
# Finished with image 86  from movie
# Finished with image 87  from movie
# Finished with image 88  from movie
# Finished with image 89  from movie
# Finished with image 90  from movie
# Finished with image 91  from movie
# Finished with image 92  from movie
# Finished with image 93  from movie
# Finished with image 94  from movie
# Finished with image 95  from movie
# Finished with image 96  from movie
# Finished with image 97  from movie
# Finished with image 98  from movie
# Finished with image 99  from movie
# Finished with image 100  from movie
# Finished with image 101  from movie
# Finished with image 102  from movie
# Finished with image 103  from movie
# Finished with image 104  from movie
# Finished with image 105  from movie
# Finished with image 106  from movie
# Finished with image 107  from movie
# Finished with image 108  from movie
# Finished with image 109  from movie
# Finished with image 110  from movie
# Finished with image 111  from movie
# Finished with image 112  from movie
# Finished with image 113  from movie
# Finished with image 114  from movie
# Finished with image 115  from movie
# Finished with image 116  from movie
# Finished with image 117  from movie
# Finished with image 118  from movie
# Finished with image 119  from movie
# Finished with image 120  from movie
# Finished with image 121  from movie
# Finished with image 122  from movie
# Finished with image 123  from movie
# Finished with image 124  from movie
# Finished with image 125  from movie
# Finished with image 126  from movie
# Finished with image 127  from movie
# Finished with image 128  from movie
# Finished with image 129  from movie
# Finished with image 130  from movie
# Finished with image 131  from movie
# Finished with image 132  from movie
# Finished with image 133  from movie
# Finished with image 134  from movie
# Finished with image 135  from movie
# Finished with image 136  from movie
# Finished with image 137  from movie
# Finished with image 138  from movie
# Finished with image 139  from movie
# Finished with image 140  from movie
# Finished with image 141  from movie
# Finished with image 142  from movie
# Finished with image 143  from movie
# Finished with image 144  from movie
# Finished with image 145  from movie
# Finished with image 146  from movie
# Finished with image 147  from movie
# Finished with image 148  from movie
# Finished with image 149  from movie
# Finished with image 150  from movie
# Finished with image 151  from movie
# Finished with image 152  from movie
# Finished with image 153  from movie
# Finished with image 154  from movie
# Finished with image 155  from movie
# Finished with image 156  from movie
# Finished with image 157  from movie
# Finished with image 158  from movie
# Finished with image 159  from movie
# Finished with image 160  from movie
# Finished with image 161  from movie
# Finished with image 162  from movie
# Finished with image 163  from movie
# Finished with image 164  from movie
# Finished with image 165  from movie
# Finished with image 166  from movie
# Finished with image 167  from movie
# Finished with image 168  from movie
# Finished with image 169  from movie
# Finished with image 170  from movie
# Finished with image 171  from movie
# Finished with image 172  from movie
# Finished with image 173  from movie
# Finished with image 174  from movie
# Finished with image 175  from movie
# Finished with image 176  from movie
# Finished with image 177  from movie
# Finished with image 178  from movie
# Finished with image 179  from movie
# Finished with image 180  from movie
# Finished with image 181  from movie
# Finished with image 182  from movie
# Finished with image 183  from movie
# Finished with image 184  from movie
# Finished with image 185  from movie
# Finished with image 186  from movie
# Finished with image 187  from movie
# Finished with image 188  from movie
# Finished with image 189  from movie
# Finished with image 190  from movie
# Finished with image 191  from movie
# Finished with image 192  from movie
# Finished with image 193  from movie
# Finished with image 194  from movie
# Finished with image 195  from movie
# Finished with image 196  from movie
# Finished with image 197  from movie
# Finished with image 198  from movie
# Finished with image 199  from movie
# Finished with image 200  from movie
# Finished with image 201  from movie
# Finished with image 202  from movie
# Finished with image 203  from movie
# Finished with image 204  from movie
# Finished with image 205  from movie
# Finished with image 206  from movie
# Finished with image 207  from movie
# Finished with image 208  from movie
# Finished with image 209  from movie
# Finished with image 210  from movie
# Finished with image 211  from movie
# Finished with image 212  from movie
# Finished with image 213  from movie
# Finished with image 214  from movie
# Finished with image 215  from movie
# Finished with image 216  from movie
# Finished with image 217  from movie
# Finished with image 218  from movie
# Finished with image 219  from movie
# Finished with image 220  from movie
# Finished with image 221  from movie
# Finished with image 222  from movie
# Finished with image 223  from movie
# Finished with image 224  from movie
# Finished with image 225  from movie
# Finished with image 226  from movie
# Finished with image 227  from movie
# Finished with image 228  from movie
# Finished with image 229  from movie
# Finished with image 230  from movie
# Finished with image 231  from movie
# Finished with image 232  from movie
# Finished with image 233  from movie
# Finished with image 234  from movie
# Finished with image 235  from movie
# Finished with image 236  from movie
# Finished with image 237  from movie
# Finished with image 238  from movie
# Finished with image 239  from movie
# Finished with image 240  from movie
# Finished with image 241  from movie
# Finished with image 242  from movie
# Finished with image 243  from movie
# Finished with image 244  from movie
# Finished with image 245  from movie
# Finished with image 246  from movie
# Finished with image 247  from movie
# Finished with image 248  from movie
# Finished with image 249  from movie
# Finished with image 250  from movie
# Finished with image 251  from movie
# Finished with image 252  from movie
# Finished with image 253  from movie
# Finished with image 254  from movie
# Finished with image 255  from movie
# Finished with image 256  from movie
# Finished with image 257  from movie
# Finished with image 258  from movie
# Finished with image 259  from movie
# Finished with image 260  from movie
# Finished with image 261  from movie
# Finished with image 262  from movie
# Finished with image 263  from movie
# Finished with image 264  from movie
# Finished with image 265  from movie
# Finished with image 266  from movie
# Finished with image 267  from movie
# Finished with image 268  from movie
# Finished with image 269  from movie
# Finished with image 270  from movie
# Finished with image 271  from movie
# Finished with image 272  from movie
# Finished with image 273  from movie
# Finished with image 274  from movie
# Finished with image 275  from movie
# Finished with image 276  from movie
# Finished with image 277  from movie
# Finished with image 278  from movie
# Finished with image 279  from movie
# Finished with image 280  from movie
# Finished with image 281  from movie
# Finished with image 282  from movie
# Finished with image 283  from movie
# Finished with image 284  from movie
# Finished with image 285  from movie
# Finished with image 286  from movie
# Finished with image 287  from movie
# Finished with image 288  from movie
# Finished with image 289  from movie
# Finished with image 290  from movie
# Finished with image 291  from movie
# Finished with image 292  from movie
# Finished with image 293  from movie
# Finished with image 294  from movie
# ...
# Finished with image 812  from movie
# Finished with image 813  from movie
# Finished with image 814  from movie
# Finished with image 815  from movie
# Finished with image 816  from movie
# Finished with image 817  from movie
# Finished with image 818  from movie
# Finished with image 819  from movie
# Finished with image 820  from movie
# Finished with image 821  from movie
# Finished with image 822  from movie
# Finished with image 823  from movie
# Finished with image 824  from movie
# Finished with image 825  from movie
# Finished with image 826  from movie
# Finished with image 827  from movie
# Finished with image 828  from movie
# Finished with image 829  from movie
# Finished with image 830  from movie
# Finished with image 831  from movie
# Finished with image 832  from movie
# Finished with image 833  from movie
# Finished with image 834  from movie
# Finished with image 835  from movie
# Finished with image 836  from movie
# Finished with image 837  from movie
# Finished with image 838  from movie
# Finished with image 839  from movie
# Finished with image 840  from movie
# Finished with image 841  from movie
# Finished with image 842  from movie
# Finished with image 843  from movie
# Finished with image 844  from movie
# Finished with image 845  from movie
# Finished with image 846  from movie
# Finished with image 847  from movie
# Finished with image 848  from movie
# Finished with image 849  from movie
# Finished with image 850  from movie
# Finished with image 851  from movie
# Finished with image 852  from movie
# Finished with image 853  from movie
# Finished with image 854  from movie
# Finished with image 855  from movie
# Finished with image 856  from movie
# Finished with image 857  from movie
# Finished with image 858  from movie
# Finished with image 859  from movie
# Finished with image 860  from movie
# Finished with image 861  from movie
# Finished with image 862  from movie
# Finished with image 863  from movie
# Finished with image 864  from movie
# Finished with image 865  from movie
# Finished with image 866  from movie
# Finished with image 867  from movie
# Finished with image 868  from movie
# Finished with image 869  from movie
# Finished with image 870  from movie
# Finished with image 871  from movie
# Finished with image 872  from movie
# Finished with image 873  from movie
# Finished with image 874  from movie
# Finished with image 875  from movie
# Finished with image 876  from movie
# Finished with image 877  from movie
# Finished with image 878  from movie
# Finished with image 879  from movie
# Finished with image 880  from movie
# Finished with image 881  from movie
# Finished with image 882  from movie
# Finished with image 883  from movie
# Finished with image 884  from movie
# Finished with image 885  from movie
# Finished with image 886  from movie
# Finished with image 887  from movie
# Finished with image 888  from movie
# Finished with image 889  from movie
# Finished with image 890  from movie
# Finished with image 891  from movie
# Finished with image 892  from movie
# Finished with image 893  from movie
# Finished with image 894  from movie
# Finished with image 895  from movie
# Finished with image 896  from movie
# Finished with image 897  from movie
# Finished with image 898  from movie
# Finished with image 899  from movie
# Finished with image 900  from movie
# Finished with image 901  from movie
# Finished with image 902  from movie
# Finished with image 903  from movie
# Finished with image 904  from movie
# Finished with image 905  from movie
# Finished with image 906  from movie
# Finished with image 907  from movie
# Finished with image 908  from movie
# Finished with image 909  from movie
# Finished with image 910  from movie
# Finished with image 911  from movie
# Finished with image 912  from movie
# Finished with image 913  from movie
# Finished with image 914  from movie
# Finished with image 915  from movie
# Finished with image 916  from movie
# Finished with image 917  from movie
# Finished with image 918  from movie
# Finished with image 919  from movie
# Finished with image 920  from movie
# Finished with image 921  from movie
# Finished with image 922  from movie
# Finished with image 923  from movie
# Finished with image 924  from movie
# Finished with image 925  from movie
# Finished with image 926  from movie
# Finished with image 927  from movie
# Finished with image 928  from movie
# Finished with image 929  from movie
# Finished with image 930  from movie
# Finished with image 931  from movie
# Finished with image 932  from movie
# Finished with image 933  from movie
# Finished with image 934  from movie
# Finished with image 935  from movie
# Finished with image 936  from movie
# Finished with image 937  from movie
# Finished with image 938  from movie
# Finished with image 939  from movie
# Finished with image 940  from movie
# Finished with image 941  from movie
# Finished with image 942  from movie
# Finished with image 943  from movie
# Finished with image 944  from movie
# Finished with image 945  from movie
# Finished with image 946  from movie
# Finished with image 947  from movie
# Finished with image 948  from movie
# Finished with image 949  from movie
# Finished with image 950  from movie
# Finished with image 951  from movie
# Finished with image 952  from movie
# Finished with image 953  from movie
# Finished with image 954  from movie
# Finished with image 955  from movie
# Finished with image 956  from movie
# Finished with image 957  from movie
# Finished with image 958  from movie
# Finished with image 959  from movie
# Finished with image 960  from movie
# Finished with image 961  from movie
# Finished with image 962  from movie
# Finished with image 963  from movie
# Finished with image 964  from movie
# Finished with image 965  from movie
# Finished with image 966  from movie
# Finished with image 967  from movie
# Finished with image 968  from movie
# Finished with image 969  from movie
# Finished with image 970  from movie
# Finished with image 971  from movie
# Finished with image 972  from movie
# Finished with image 973  from movie
# Finished with image 974  from movie
# Finished with image 975  from movie
# Finished with image 976  from movie
# Finished with image 977  from movie
# Finished with image 978  from movie
# Finished with image 979  from movie
# Finished with image 980  from movie
# Finished with image 981  from movie
# Finished with image 982  from movie
# Finished with image 983  from movie
# Finished with image 984  from movie
# Finished with image 985  from movie
# Finished with image 986  from movie
# Finished with image 987  from movie
# Finished with image 988  from movie
# Finished with image 989  from movie
# Finished with image 990  from movie
# Finished with image 991  from movie
# Finished with image 992  from movie
# Finished with image 993  from movie
# Finished with image 994  from movie
# Finished with image 995  from movie
# Finished with image 996  from movie
# Finished with image 997  from movie
# Finished with image 998  from movie
# Finished with image 999  from movie
# Please wait while data is mapped to: /Users/js0403/miniscope/HPC-Neurons/134A/AAV2/3-Syn-GCaMP8f/2024_02_06/12_35_54/miniscopeDeviceName/4.tif
# Finished with image 0  from movie
# Finished with image 1  from movie
# Finished with image 2  from movie
# Finished with image 3  from movie
# Finished with image 4  from movie
# Finished with image 5  from movie
# Finished with image 6  from movie
# Finished with image 7  from movie
# Finished with image 8  from movie
# Finished with image 9  from movie
# Finished with image 10  from movie
# Finished with image 11  from movie
# Finished with image 12  from movie
# Finished with image 13  from movie
# Finished with image 14  from movie
# Finished with image 15  from movie
# Finished with image 16  from movie
# Finished with image 17  from movie
# Finished with image 18  from movie
# Finished with image 19  from movie
# Finished with image 20  from movie
# Finished with image 21  from movie
# Finished with image 22  from movie
# Finished with image 23  from movie
# Finished with image 24  from movie
# Finished with image 25  from movie
# Finished with image 26  from movie
# Finished with image 27  from movie
# Finished with image 28  from movie
# Finished with image 29  from movie
# Finished with image 30  from movie
# Finished with image 31  from movie
# Finished with image 32  from movie
# Finished with image 33  from movie
# Finished with image 34  from movie
# Finished with image 35  from movie
# Finished with image 36  from movie
# Finished with image 37  from movie
# Finished with image 38  from movie
# Finished with image 39  from movie
# Finished with image 40  from movie
# Finished with image 41  from movie
# Finished with image 42  from movie
# Finished with image 43  from movie
# Finished with image 44  from movie
# Finished with image 45  from movie
# Finished with image 46  from movie
# Finished with image 47  from movie
# Finished with image 48  from movie
# Finished with image 49  from movie
# Finished with image 50  from movie
# Finished with image 51  from movie
# Finished with image 52  from movie
# Finished with image 53  from movie
# Finished with image 54  from movie
# Finished with image 55  from movie
# Finished with image 56  from movie
# Finished with image 57  from movie
# Finished with image 58  from movie
# Finished with image 59  from movie
# Finished with image 60  from movie
# Finished with image 61  from movie
# Finished with image 62  from movie
# Finished with image 63  from movie
# Finished with image 64  from movie
# Finished with image 65  from movie
# Finished with image 66  from movie
# Finished with image 67  from movie
# Finished with image 68  from movie
# Finished with image 69  from movie
# Finished with image 70  from movie
# Finished with image 71  from movie
# Finished with image 72  from movie
# Finished with image 73  from movie
# Finished with image 74  from movie
# Finished with image 75  from movie
# Finished with image 76  from movie
# Finished with image 77  from movie
# Finished with image 78  from movie
# Finished with image 79  from movie
# Finished with image 80  from movie
# Finished with image 81  from movie
# Finished with image 82  from movie
# Finished with image 83  from movie
# Finished with image 84  from movie
# Finished with image 85  from movie
# Finished with image 86  from movie
# Finished with image 87  from movie
# Finished with image 88  from movie
# Finished with image 89  from movie
# Finished with image 90  from movie
# Finished with image 91  from movie
# Finished with image 92  from movie
# Finished with image 93  from movie
# Finished with image 94  from movie
# Finished with image 95  from movie
# Finished with image 96  from movie
# Finished with image 97  from movie
# Finished with image 98  from movie
# Finished with image 99  from movie
# Finished with image 100  from movie
# Finished with image 101  from movie
# Finished with image 102  from movie
# Finished with image 103  from movie
# Finished with image 104  from movie
# Finished with image 105  from movie
# Finished with image 106  from movie
# Finished with image 107  from movie
# Finished with image 108  from movie
# Finished with image 109  from movie
# Finished with image 110  from movie
# Finished with image 111  from movie
# Finished with image 112  from movie
# Finished with image 113  from movie
# Finished with image 114  from movie
# Finished with image 115  from movie
# Finished with image 116  from movie
# Finished with image 117  from movie
# Finished with image 118  from movie
# Finished with image 119  from movie
# Finished with image 120  from movie
# Finished with image 121  from movie
# Finished with image 122  from movie
# Finished with image 123  from movie
# Finished with image 124  from movie
# Finished with image 125  from movie
# Finished with image 126  from movie
# Finished with image 127  from movie
# Finished with image 128  from movie
# Finished with image 129  from movie
# Finished with image 130  from movie
# Finished with image 131  from movie
# Finished with image 132  from movie
# Finished with image 133  from movie
# Finished with image 134  from movie
# Finished with image 135  from movie
# Finished with image 136  from movie
# Finished with image 137  from movie
# Finished with image 138  from movie
# Finished with image 139  from movie
# Finished with image 140  from movie
# Finished with image 141  from movie
# Finished with image 142  from movie
# Finished with image 143  from movie
# Finished with image 144  from movie
# Finished with image 145  from movie
# Finished with image 146  from movie
# Finished with image 147  from movie
# Finished with image 148  from movie
# Finished with image 149  from movie
# Finished with image 150  from movie
# Finished with image 151  from movie
# Finished with image 152  from movie
# Finished with image 153  from movie
# Finished with image 154  from movie
# Finished with image 155  from movie
# Finished with image 156  from movie
# Finished with image 157  from movie
# Finished with image 158  from movie
# Finished with image 159  from movie
# Finished with image 160  from movie
# Finished with image 161  from movie
# Finished with image 162  from movie
# Finished with image 163  from movie
# Finished with image 164  from movie
# Finished with image 165  from movie
# Finished with image 166  from movie
# Finished with image 167  from movie
# Finished with image 168  from movie
# Finished with image 169  from movie
# Finished with image 170  from movie
# Finished with image 171  from movie
# Finished with image 172  from movie
# Finished with image 173  from movie
# Finished with image 174  from movie
# Finished with image 175  from movie
# Finished with image 176  from movie
# Finished with image 177  from movie
# Finished with image 178  from movie
# Finished with image 179  from movie
# Finished with image 180  from movie
# Finished with image 181  from movie
# Finished with image 182  from movie
# Finished with image 183  from movie
# Finished with image 184  from movie
# Finished with image 185  from movie
# Finished with image 186  from movie
# Finished with image 187  from movie
# Finished with image 188  from movie
# Finished with image 189  from movie
# Finished with image 190  from movie
# Finished with image 191  from movie
# Finished with image 192  from movie
# Finished with image 193  from movie
# Finished with image 194  from movie
# Finished with image 195  from movie
# Finished with image 196  from movie
# Finished with image 197  from movie
# Finished with image 198  from movie
# Finished with image 199  from movie
# Finished with image 200  from movie
# Finished with image 201  from movie
# Finished with image 202  from movie
# Finished with image 203  from movie
# Finished with image 204  from movie
# Finished with image 205  from movie
# Finished with image 206  from movie
# Finished with image 207  from movie
# Finished with image 208  from movie
# Finished with image 209  from movie
# Finished with image 210  from movie
# Finished with image 211  from movie
# Finished with image 212  from movie
# Finished with image 213  from movie
# Finished with image 214  from movie
# Finished with image 215  from movie
# Finished with image 216  from movie
# Finished with image 217  from movie
# Finished with image 218  from movie
# Finished with image 219  from movie
# Finished with image 220  from movie
# Finished with image 221  from movie
# Finished with image 222  from movie
# Finished with image 223  from movie
# Finished with image 224  from movie
# Finished with image 225  from movie
# Finished with image 226  from movie
# Finished with image 227  from movie
# Finished with image 228  from movie
# Finished with image 229  from movie
# Finished with image 230  from movie
# Finished with image 231  from movie
# Finished with image 232  from movie
# Finished with image 233  from movie
# Please wait while data is mapped to: /Users/js0403/miniscope/HPC-Neurons/134A/AAV2/3-Syn-GCaMP8f/2024_02_06/12_35_54/miniscopeDeviceName/full_movie.tif
# 1000
# Finished with image 1001 / 5
# 2000
# Finished with image 2001 / 5
# 3000
# Finished with image 3001 / 5
# 4000
# Finished with image 4001 / 5
# 4234
# Finished with image 4235 / 5
